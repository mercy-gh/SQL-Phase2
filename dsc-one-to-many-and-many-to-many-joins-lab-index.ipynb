# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge of one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# * Explain one-to-many and many-to-many joins as well as implications for the size of query results
# * Query data using one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='https://curriculum-content.s3.amazonaws.com/data-science/images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database
#
# Include the relevant imports, then connect to the database located at `data.sqlite`.

# %%
# Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect("data.sqlite")

# %% [markdown]
# ## Employees and Their Offices (a One-to-One Join)
#
# Select all of the employees including their first name and last name along with the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
# Your code here
pd.read_sql("""
            SELECT firstName, LastName, city, state
            FROM employees
            JOIN offices USING(officeCode)
            ORDER BY firstName, lastName
            """, conn)
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and Their Orders (a One-to-Many Join)
#
# Select all of the customer contacts (first and last names) along with details for each of the customers' order numbers, order dates, and statuses.

# %%
# Your code here
pd.read_sql("""
            SELECT customerName, contactLastName, orderNumber, orderDate, status
            FROM customers
            JOIN orders USING(customerNumber)
            ORDER BY customerName, contactLastName
            """, conn)
# Out:
#                     customerName contactLastName orderNumber   orderDate  \
# 0                 AV Stores, Co.        Ashworth       10110  2003-03-18
# 1                 AV Stores, Co.        Ashworth       10306  2004-10-14
# 2                 AV Stores, Co.        Ashworth       10332  2004-11-17
# 3                   Alpha Cognac          Roulet       10136  2003-07-04
# 4                   Alpha Cognac          Roulet       10178  2003-11-08
# ..                           ...             ...         ...         ...
# 321     Volvo Model Replicas, Co        Berglund       10334  2004-11-19
# 322  West Coast Collectables Co.        Thompson       10199  2003-12-01
# 323  West Coast Collectables Co.        Thompson       10215  2004-01-29
# 324            giftsbymail.co.uk         Bennett       10232  2004-03-20
# 325            giftsbymail.co.uk         Bennett       10316  2004-11-01
#
#       status
# 0    Shipped
# 1    Shipped
# 2    Shipped
# 3    Shipped
# 4    Shipped
# ..       ...
# 321  On Hold
# 322  Shipped
# 323  Shipped
# 324  Shipped
# 325  Shipped
#
# [326 rows x 5 columns]

# %% [markdown]
# ## Customers and Their Payments (Another One-to-Many Join)
#
# Select all of the customer contacts (first and last names) along with details for each of the customers' payment amounts and date of payment. Sort these results in descending order by the payment amount.

# %%
# Your code here
pd.read_sql("""
            SELECT customerName, contactLastName, amount, paymentDate
            FROM customers
            LEFT JOIN payments USING(customerNumber)
            ORDER BY amount DESC
            """, conn)
# Out:
#                      customerName contactLastName   amount paymentDate
# 0                FunGiftIdeas.com         Benitez  9977.85  2003-11-08
# 1     Australian Gift Network, Co        Calaghan  9821.32  2003-10-17
# 2         Auto-Moto Classics Inc.          Taylor  9658.74  2004-12-06
# 3    Australian Collectables, Ltd        Clenahan  9415.13  2004-07-28
# 4                 Mini Auto Werke          Mendel  8807.12  2005-05-03
# ..                            ...             ...      ...         ...
# 292              Warburg Exchange         Ottlieb     None        None
# 293           Anton Designs, Ltd.           Anton     None        None
# 294           Mit Vergnügen & Co.            Moos     None        None
# 295     Kremlin Collectables, Co.         Semenov     None        None
# 296            Raanan Stores, Inc     Altagar,G M     None        None
#
# [297 rows x 4 columns]

# %% [markdown]
# ## Orders, Order Details, and Product Details (a Many-to-Many Join)

# %% [markdown]
# Select all of the customer contacts (first and last names) along with the product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# > Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries that can make complex queries such as this much simpler!

# %%
# Your code here
pd.read_sql("""
            SELECT customerName, contactLastName, productName, quantityOrdered, orderDate
            FROM customers
            LEFT JOIN orders USING(customerNumber)
            LEFT JOIN orderdetails USING(orderNumber)
            LEFT JOIN products USING(productCode)
            ORDER BY orderDate DESC
            """, conn)
# Out:
#                    customerName contactLastName  \
# 0             La Rochelle Gifts         Labrune
# 1             La Rochelle Gifts         Labrune
# 2             La Rochelle Gifts         Labrune
# 3             La Rochelle Gifts         Labrune
# 4             La Rochelle Gifts         Labrune
# ...                         ...             ...
# 3015           Warburg Exchange         Ottlieb
# 3016        Anton Designs, Ltd.           Anton
# 3017        Mit Vergnügen & Co.            Moos
# 3018  Kremlin Collectables, Co.         Semenov
# 3019         Raanan Stores, Inc     Altagar,G M
#
#                          productName quantityOrdered   orderDate
# 0             1962 LanciaA Delta 16V              38  2005-05-31
# 1                  1957 Chevy Pickup              33  2005-05-31
# 2     1998 Chrysler Plymouth Prowler              28  2005-05-31
# 3             1964 Mercedes Tour Bus              38  2005-05-31
# 4              1926 Ford Fire Engine              19  2005-05-31
# ...                              ...             ...         ...
# 3015                            None            None        None
# 3016                            None            None        None
# 3017                            None            None        None
# 3018                            None            None        None
# 3019                            None            None        None
#
# [3020 rows x 5 columns]

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge of one-to-many and many-to-many relationships!
